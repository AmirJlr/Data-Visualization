# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.xkcd()

# %%
epl_df =pd.read_csv('EPL_21.csv',encoding='latin-1')#or encoding='ISO-8859-1'

# %%
epl_df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
epl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
epl_df.describe()
# Out:
#               Age     Matches      Starts         Mins       Goals  \
# count  532.000000  532.000000  532.000000   532.000000  532.000000
# mean    25.500000   19.535714   15.714286  1411.443609    1.853383
# std      4.319404   11.840459   11.921161  1043.171856    3.338009
# min     16.000000    1.000000    0.000000     1.000000    0.000000
# 25%     22.000000    9.000000    4.000000   426.000000    0.000000
# 50%     26.000000   21.000000   15.000000  1345.000000    1.000000
# 75%     29.000000   30.000000   27.000000  2303.500000    2.000000
# max     38.000000   38.000000   38.000000  3420.000000   23.000000
#
#           Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# count  532.000000        532.000000             532.000000     532.000000
# mean     1.287594        717.750000              77.823872       0.191729
# std      2.095191        631.372522              13.011631       0.850881
# ...

# %%
# finding null values
epl_df.isna().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
#create 2 new columns

epl_df['MinsPerMatch'] = (epl_df['Mins']/epl_df['Matches']).astype(int)
epl_df['GoalsPerMatch'] = (epl_df['Goals']/epl_df['Matches']).astype(float)

# %%
epl_df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
#total goals
TotalGoals = epl_df['Goals'].sum()

# %%
#penalty goals
TotalPenaltyGoals = epl_df['Penalty_Goals'].sum()

#penalty attempts
TotalPenaltyAttempts=epl_df['Penalty_Attempted'].sum()

#missed penalty
MissedPenalty=TotalPenaltyAttempts-TotalPenaltyGoals

# %%
plt.figure(figsize=(10,6))
data=[TotalPenaltyAttempts,MissedPenalty]
labels=['TotalPenaltyAttempts','MissedPenalty']
color=sns.color_palette('Set2')

plt.pie(data,labels=labels,colors=color,explode=[.1,.1],autopct='%1.1f%%');

# %%
plt.pie([TotalGoals,TotalPenaltyGoals],labels=['TotalGoals','TotalPenaltyGoals'],explode=[.1,.1],radius=1.5);

# %%
epl_df.head(2)
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  MinsPerMatch  \
# 0                  1  0.21  0.24             2          0            80
# 1                  0  0.00  0.00             2          0            88
#
#    GoalsPerMatch
# 0       0.166667
# 1       0.000000

# %%
#Position

epl_df['Position'].unique()
# Out:
# array(['MF,FW', 'GK', 'FW', 'DF', 'MF', 'FW,MF', 'FW,DF', 'DF,MF',
#        'MF,DF', 'DF,FW'], dtype=object)

# %%
#Position

GK=len(epl_df[epl_df['Position']=='GK'])
DF=len(epl_df[epl_df['Position']=='DF'])
MF=len(epl_df[epl_df['Position']=='MF'])
FW=len(epl_df[epl_df['Position']=='FW'])

# %%
#pie for position
plt.figure(figsize=(10,8))
data=[GK,DF,MF,FW]
label=['GK','DF','MF','FW']
color=sns.color_palette('Set2')

plt.pie(data,labels=label,colors=color,autopct='%1.1f%%');

# %%
#Nation Distribution

#1
#len(epl_df['Nationality'].unique())

np.size(epl_df['Nationality'].unique())
# Out:
# 59

# %%
nationality = epl_df.groupby('Nationality').size().sort_values(ascending=False)

nationality.head(10).plot(figsize=(12,8),kind='barh',color=sns.color_palette('Set2'))
# Out:
# <AxesSubplot:ylabel='Nationality'>

# %%
#most player in club in 2ways:

#1
epl_df.groupby('Club').size().sort_values(ascending=False)
# Out:
# Club
# West Bromwich Albion       30
# Arsenal                    29
# Southampton                29
# Everton                    29
# Manchester United          29
# Liverpool FC               28
# Fulham                     28
# Brighton                   27
# Chelsea                    27
# Wolverhampton Wanderers    27
# Newcastle United           27
# Sheffield United           27
# Leicester City             27
# Burnley                    25
# West Ham United            24
# Manchester City            24
# Crystal Palace             24
# Tottenham Hotspur          24
# Aston Villa                24
# Leeds United               23
# dtype: int64

# %%
#2
epl_df['Club'].value_counts().nlargest(10)
# Out:
# West Bromwich Albion       30
# Everton                    29
# Manchester United          29
# Southampton                29
# Arsenal                    29
# Liverpool FC               28
# Fulham                     28
# Leicester City             27
# Brighton                   27
# Wolverhampton Wanderers    27
# Name: Club, dtype: int64

# %%
#least player in club in 2ways:

# %%
#1
epl_df.groupby('Club').size().sort_values()
# Out:
# Club
# Leeds United               23
# Aston Villa                24
# Tottenham Hotspur          24
# Crystal Palace             24
# Manchester City            24
# West Ham United            24
# Burnley                    25
# Leicester City             27
# Sheffield United           27
# Newcastle United           27
# Wolverhampton Wanderers    27
# Chelsea                    27
# Brighton                   27
# Fulham                     28
# Liverpool FC               28
# Manchester United          29
# Everton                    29
# Southampton                29
# Arsenal                    29
# West Bromwich Albion       30
# dtype: int64

# %%
#2
epl_df['Club'].value_counts().nsmallest()
# Out:
# Leeds United         23
# Tottenham Hotspur    24
# West Ham United      24
# Crystal Palace       24
# Aston Villa          24
# Name: Club, dtype: int64

# %%
#Age Disrtibution

under_20 = epl_df[epl_df['Age']<20]
age_20_25 = epl_df[(epl_df['Age'] >= 20) & (epl_df['Age'] < 25)]
age_25_30 = epl_df[(epl_df['Age'] >= 25) & (epl_df['Age'] < 30)]
above30 = epl_df[epl_df['Age']<=30]

# %%
# Pie Chart for Age
plt.figure(figsize=(12,8))
plt.title('Age Disrtibution',fontsize=25)

data=[len(under_20),len(age_20_25),len(age_25_30),len(above30)]
label=['age < 20','20 <= age < 25','25 <= age < 30','age >= 30']
color=sns.color_palette('Set2')

plt.pie(data,labels=label,colors=color,autopct='%.1f%%');

# %%
#under 20 analyse
plt.figure(figsize=(12,8))
under_20['Club'].value_counts().plot(kind='barh',color=color)
# Out:
# <AxesSubplot:>

# %%
#find ManU youngs

under_20[under_20['Club']=='Manchester United']
# Out:
#                    Name               Club Nationality Position  Age  Matches  \
# 61      Mason Greenwood  Manchester United         ENG       FW   18       31
# 72     Brandon Williams  Manchester United         ENG       DF   19        4
# 73          Amad Diallo  Manchester United         CIV       FW   18        3
# 74       Anthony Elanga  Manchester United         SWE       FW   18        2
# 76      Shola Shoretire  Manchester United         ENG       FW   16        2
# 78      Hannibal Mejbri  Manchester United         FRA       MF   17        1
# 79  William Thomas Fish  Manchester United         ENG       DF   17        1
#
#     Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 61      21  1822      7        2               732                   83.1
# 72       2   188      0        0               140                   85.7
# 73       2   166      0        1                64                   84.4
# ...

# %%
#mean age per club
plt.title('Mean Age Per Club',fontsize=25)
epl_df.groupby('Club')['Age'].mean().plot(kind='bar',figsize=(13,9),color=sns.color_palette('rocket'));

# %%
plt.figure(figsize=(13,9))
sns.boxplot(x='Club',y='Age',data=epl_df);
plt.xticks(rotation=90);
plt.savefig('box-xkcd.png')

# %%
most_assist=epl_df.groupby('Club')['Assists'].sum().sort_values(ascending=False)

plt.title('Most Assist per Club',fontsize=25)
most_assist.plot(kind='barh',figsize=(13,9),color=sns.color_palette('magma'));

# %%
most_goal=epl_df.groupby('Club')['Goals'].sum().sort_values(ascending=False)


plt.title('Most Goal per Club',fontsize=25)
most_goal.plot(kind='barh',figsize=(13,9),color=sns.color_palette('magma'));

# %%
#top 10 goal

top_goals = epl_df[['Name','Club','Goals','Matches']].nlargest(n=10,columns='Goals')

sns.barplot(x='Name',y='Goals',data=top_goals);
plt.xticks(rotation=90);

# %%
#top 10 assists
top_assists=epl_df[['Name','Club','Assists','Matches']].nlargest(n=10,columns='Assists')

sns.barplot(x='Name',y='Assists',data=top_assists);
plt.xticks(rotation=90);

# %%
#goals per match
epl_df.head(2)
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  MinsPerMatch  \
# 0                  1  0.21  0.24             2          0            80
# 1                  0  0.00  0.00             2          0            88
#
#    GoalsPerMatch
# 0       0.166667
# 1       0.000000

# %%
epl_df.nlargest(n=5,columns='GoalsPerMatch')
# Out:
#               Name               Club Nationality Position  Age  Matches  \
# 162     Harry Kane  Tottenham Hotspur         ENG       FW   27       35
# 81   Mohamed Salah       Liverpool FC         EGY       FW   28       37
# 307    Joe Willock   Newcastle United         ENG       MF   20       14
# 145  Jesse Lingard    West Ham United         ENG    MF,FW   27       16
# 175    Gareth Bale  Tottenham Hotspur         WAL       FW   31       20
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 162      35  3082     23       14               937                   70.1
# 81       34  3078     22        5              1288                   83.2
# 307      11   978      8        0               235                   77.0
# 145      16  1421      9        4               669                   81.3
# 175      10   920     11        2               408                   69.6
#
# ...

# %%
len(epl_df.nlargest(n=5,columns='GoalsPerMatch'))
# Out:
# 5

# %%
#top 10 yello & red cards
top_red_cards = epl_df.nlargest(n=5,columns='Red_Cards')

# %%
top_red_cards
# Out:
#                     Name             Club Nationality Position  Age  Matches  \
# 397           Lewis Dunk         Brighton         ENG       DF   28       33
# 5      César Azpilicueta          Chelsea         ESP       DF   30       26
# 8           Thiago Silva          Chelsea         BRA       DF   35       23
# 14   Andreas Christensen          Chelsea         DEN       DF   24       17
# 31          João Cancelo  Manchester City         POR       DF   26       28
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 397      33  2931      5        0              2151                   90.0
# 5        24  2188      1        2              2015                   87.5
# 8        23  1935      2        0              1871                   93.5
# 14       15  1371      0        0              1089                   92.8
# 31       27  2299      2        3              2094                   85.7
#
# ...
